# %% [markdown]
# <a href="https://colab.research.google.com/github/anthonyhu25/Bayesian-Queuing-/blob/main/4_1_1_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 Problem Setup

# %% [markdown]
# This [paper](https://arxiv.org/pdf/2202.07581) is taking a Bayesian Stochastic Gradient Descent (SGD) approach towards stochastic optimization of a batch of streaming data every time interval, in the decision-indepedent and decision-independent case. In stochastic simulation optimization, there has been much work done on decision-independent (exogenous) data, but
